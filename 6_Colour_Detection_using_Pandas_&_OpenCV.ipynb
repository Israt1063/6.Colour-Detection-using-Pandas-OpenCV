# %% [markdown]
# <a href="https://colab.research.google.com/github/Israt1063/6.Colour-Detection-using-Pandas-OpenCV/blob/main/6_Colour_Detection_using_Pandas_%26_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/codebrainz/color-names/master/output/colors.csv'

df = pd.read_csv(url)

# The columns are: name, hex, r, g, b
# Let's rename columns for clarity
df.rename(columns={'name': 'color_name', 'r': 'R', 'g': 'G', 'b': 'B'}, inplace=True)

print(df.head())
# Out:
#      air_force_blue_raf   Air Force Blue (Raf)  #5d8aa8   93  138  168
# 0   air_force_blue_usaf  Air Force Blue (Usaf)  #00308f    0   48  143
# 1  air_superiority_blue   Air Superiority Blue  #72a0c1  114  160  193
# 2       alabama_crimson        Alabama Crimson  #a32638  163   38   56
# 3            alice_blue             Alice Blue  #f0f8ff  240  248  255
# 4      alizarin_crimson       Alizarin Crimson  #e32636  227   38   54

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-85e892e6-3dd0-4930-88ca-c76b49dc3d01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85e892e6-3dd0-4930-88ca-c76b49dc3d01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# Load image
img = cv2.imread('Screenshot 2025-05-31 at 6.34.01 PM.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Show the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
print(df.columns)
# Out:
# Index(['color_code', 'color_name', 'hex', 'R', 'G', 'B'], dtype='object')

# %%
df = pd.read_csv(url, header=None)

# %%
df.columns = ['color_code', 'color_name', 'hex', 'R', 'G', 'B']

# %%
print(df.head())
print(df.columns)
# Out:
#              color_code             color_name      hex    R    G    B
# 0    air_force_blue_raf   Air Force Blue (Raf)  #5d8aa8   93  138  168
# 1   air_force_blue_usaf  Air Force Blue (Usaf)  #00308f    0   48  143
# 2  air_superiority_blue   Air Superiority Blue  #72a0c1  114  160  193
# 3       alabama_crimson        Alabama Crimson  #a32638  163   38   56
# 4            alice_blue             Alice Blue  #f0f8ff  240  248  255
# Index(['color_code', 'color_name', 'hex', 'R', 'G', 'B'], dtype='object')

# %%
def get_closest_color_name(R, G, B):
    minimum = float('inf')
    cname = ''
    for i in range(len(df)):
        d = np.sqrt((R - int(df.loc[i, 'R']))**2 + (G - int(df.loc[i, 'G']))**2 + (B - int(df.loc[i, 'B']))**2)
        if d < minimum:
            minimum = d
            cname = df.loc[i, 'color_name']
    return cname

# Example usage
R, G, B = 62, 49, 66
color_name = get_closest_color_name(R, G, B)
print(f"Closest color name: {color_name}")
# Out:
# Closest color name: Onyx
